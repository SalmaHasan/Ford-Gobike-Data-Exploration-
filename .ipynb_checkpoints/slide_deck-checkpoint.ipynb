# %% [markdown]
# #  Ford Gobike Data Exploration
#
# ## by Salma Hasan Abokamar

# %% [markdown]
# ## Investigation Overview
#
# How long does the average trip take?(duration)
#
# Does the above depend on if a user is a subscriber or customer?
# ## Dataset Overview
#
# This data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
gbike = pd.read_csv('fordgobike.csv')
gbike.shape
# Out:
# (183412, 16)

# %% [markdown]
#  Males are more than females with large number in difference

# %%
gen_order = gbike['member_gender'].value_counts().index

base_color = sb.color_palette()[7]
sb.countplot(data=gbike, x='member_gender', color=base_color, order = gen_order)
plt.title('Gender');

# %%
sorted_counts = gbike['member_gender'].value_counts()

plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False, wedgeprops = {'width' : 0.7})


plt.axis('square')
plt.title('Gender');

# %% [markdown]
#  Trip duration values first increases and reach to tha peak the duration of the trip is around 5 min the graph is right skewed

# %%
bike = gbike.copy()
# Converting the seconds into minutes for better understanding of the graph.
bike['duration_min'] = bike['duration_sec'] / 60
bins = np.arange(0, bike['duration_min'].max()+0.1, 0.1)
plt.xlim(0,30)

plt.hist(data = bike, x = 'duration_min', bins = bins);
plt.xlabel("Duration (min)")
plt.ylabel("Counts")
plt.title("Distributuion of duration");

# %% [markdown]
# it is appear that most of trips are in bet 20 and less than 80 years and it about 10000 durations

# %%
#sb.set(rc={'figure.figsize':(11.7,8.27)})

sb.regplot(data = gbike, x =2021-gbike['member_birth_year'], y = 'duration_sec');
plt.xlabel('Age (years)')
plt.ylabel('Duration(sec)')
plt.title("Duration and Age.");

# %% [markdown]
#
#
# the higher duration trip is higher for male but percentage is higher for women and other, also other has one more peak at nearly the age of 30 years for higher duration time, for female is about two peaks

# %%
gbike['age'] = (2021 - gbike['member_birth_year'])
g = sb.FacetGrid(data = gbike, col = 'member_gender',xlim = [10, 80])
g.map(plt.scatter, 'age', 'duration_sec', alpha=0.3)
g.set_xlabels('Age (year)')
g.set_ylabels('Duration (sec)');

# %%
# !jupyter nbconvert slide_deck.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook slide_deck.ipynb to slides
# [NbConvertApp] Writing 378759 bytes to slide_deck.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\salma\Anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\salma\Anaconda3\lib\site-packages\jupyter_core\application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 340, in start
#     self.convert_notebooks()
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 510, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 483, in convert_single_notebook
#     self.postprocess_single_notebook(write_results)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 455, in postprocess_single_notebook
#     self.postprocessor(write_results)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\postprocessors\base.py", line 28, in __call__
#     self.postprocess(input)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\nbconvert\postprocessors\serve.py", line 90, in postprocess
#     http_server.listen(self.port, address=self.ip)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\tornado\tcpserver.py", line 144, in listen
#     sockets = bind_sockets(port, address=address)
#   File "C:\Users\salma\Anaconda3\lib\site-packages\tornado\netutil.py", line 163, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted

# %% [markdown]
# jupyter nbconvert "slide_deck.ipynb" --to slides --post serve --template output_toggle

# %% [markdown]
# !jupyter nbconvert "slide_deck.ipynb" --to slides --post serve --template output_toggle
